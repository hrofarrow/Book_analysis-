# %% [markdown]
# Data Exploration Process
#         - Started searching several websites with CSV and API options to get used to the process of searching for good data analyis datasets.
#     - We initially struggled with finding an API or CSV that contained enough data to do a proper analysis on.
#     - We stumbled upon the dataset we used in this analysis through a search on Kaggle.com that contained a random assortment of books.
#     - In order to set us up for success on the analysis we did some cleanup of the CSV by removing duplicate titles and dropping any rows that were missing data.

# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt

# %%
book_file = "google_books_1299.csv"
book_df = pd.read_csv(book_file)
book_df
# Out:
#       Unnamed: 0                                              title  \
# 0              0                         Attack on Titan: Volume 13
# 1              1   Antiques Roadkill: A Trash 'n' Treasures Mystery
# 2              2                     The Art of Super Mario Odyssey
# 3              3     Getting Away Is Deadly: An Ellie Avery Mystery
# 4              4          The Painted Man (The Demon Cycle, Book 1)
# ...          ...                                                ...
# 1294        1294  Twas The Nightshift Before Christmas: Festive ...
# 1295        1295  Why We Sleep: The New Science of Sleep and Dreams
# 1296        1296      How to Understand Business Finance: Edition 2
# 1297        1297                     Spider-Man: Kraven's Last Hunt
# 1298        1298           W is for Wasted: A Kinsey Millhone Novel
#
#                author  rating voters   price currency  \
# 0      Hajime Isayama     4.6    428   43.28      SAR
# ...

# %%
# clean up dataframe 
#drop empty lines 
book_df = book_df.dropna(how='any')
# drop duplicates 
new_book_df = book_df.drop_duplicates(subset="title", keep="first")
